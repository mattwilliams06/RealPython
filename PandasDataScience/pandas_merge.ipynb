# %%
import pandas as pd
import numpy as np
import urllib
import requests
import os

# %%
def download_data(url, fname, ext):
    path = os.getcwd()
    target_path = f'{fname}.{ext}'
    response = requests.get(url)
    print(f'Response: {response.raise_for_status()}')
    with open(target_path, 'wb') as file:
        file.write(response.content)
    print(f'Download of {target_path} completed to {path}')

# %%
precip_data = 'https://raw.githubusercontent.com/realpython/materials/master/introduction-combining-data-pandas-merge-join-and-concat/climate_precip.csv'

# %%
download_data(precip_data, 'climate-precip', 'csv')
# Out:
# Response: None
# Download of climate-precip.csv completed to /Users/mattwilliams/Documents/RealPython/PandasDataScience

# %%
temp_data = 'https://raw.githubusercontent.com/realpython/materials/master/introduction-combining-data-pandas-merge-join-and-concat/climate_temp.csv'

# %%
climate_temp = pd.read_csv('climate-temp.csv')

# %%
climate_precip = pd.read_csv('climate-precip.csv')

# %%
climate_temp.head()
# Out:
#              STATION            STATION_NAME ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  DLY-CLDD-BASE72  \
# ...

# %%
climate_precip.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# ...

# %%
climate_precip.shape
# Out:
# (151110, 29)

# %%
climate_temp.shape
# Out:
# (127020, 21)

# %% [markdown]
# # Inner Join
#
# Here, we'll use the default merge argument ```inner```, which will cause us to lose any rows that aren't matched between the datasets (unmatched key column rows).

# %%
precip_one_station = climate_precip[climate_precip['STATION']=='GHCND:USC00045721']

# %%
precip_one_station.head()
# Out:
#                 STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#       DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 1460             -666            -66.6             0.16             -666
# 1461             -666            -66.6             0.16             -666
# 1462             -666            -66.6             0.16             -666
# 1463             -666            -66.6             0.16             -666
# 1464             -666            -66.6             0.17             -666
#
#       DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# ...

# %%
inner_merged = pd.merge(precip_one_station, climate_temp)

# %%
inner_merged.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6             0.16             -666
# 1             -666            -66.6             0.16             -666
# 2             -666            -66.6             0.16             -666
# 3             -666            -66.6             0.16             -666
# 4             -666            -66.6             0.17             -666
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
inner_merged.shape
# Out:
# (365, 47)

# %%
precip_one_station.shape
# Out:
# (365, 29)

# %%
climate_temp[climate_temp['STATION'] == 'GHCND:USC00045721']
# Out:
#                 STATION            STATION_NAME ELEVATION LATITUDE  LONGITUDE  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# ...                 ...                     ...       ...      ...        ...
# 1820  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1821  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1822  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1823  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
# 1824  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436  -115.5469
#
# ...

# %% [markdown]
# The key column is matched for all of the rows for Mitchell Caverns between the datasets, so we didn't lose any rows during the merge. We gained all of the columns from the temperature dataset.
#
# # Outer Join

# %%
outer_merged = pd.merge(precip_one_station, climate_temp, how='outer', on=['STATION', 'DATE'])

# %%
outer_merged.head()
# Out:
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0           -666.0            -66.6             0.16           -666.0
# 1           -666.0            -66.6             0.16           -666.0
# 2           -666.0            -66.6             0.16           -666.0
# 3           -666.0            -66.6             0.16           -666.0
# 4           -666.0            -66.6             0.17           -666.0
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %%
outer_merged.shape
# Out:
# (127020, 48)

# %% [markdown]
# Here, the number of rows is the same as the original number for the larger dataset, because no rows were lost. we picked up the additional columns.
#
# # Left Merge
#
# In a left merge, the resulting dataframe will contain all of the rows in the left dataset, while discarding all of the unmatched rows from the right dataset.

# %%
left_merged = pd.merge(climate_temp, precip_one_station, how='left', on=['STATION', 'DATE'])

# %%
left_merged.shape
# Out:
# (127020, 48)

# %%
left_merged_reversed = pd.merge(precip_one_station, climate_temp, how='left', on=['STATION', 'DATE'])

# %%
left_merged_reversed.shape
# Out:
# (365, 48)

# %% [markdown]
# # Right Merge
#
# This is identical to the left merge, just with the operation reversed based off of the order of the arguments.
#
# # Pandas ```join()```

# %%
precip_one_station.join(climate_temp, lsuffix='_left', rsuffix='_right')
# Out:
#            STATION_left       STATION_NAME_left  DATE_left  DLY-PRCP-25PCTL  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US   20100101             0.04
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US   20100102             0.05
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US   20100103             0.05
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US   20100104             0.05
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US   20100105             0.05
# ...                 ...                     ...        ...              ...
# 1820  GHCND:USC00045721  MITCHELL CAVERNS CA US   20101227             0.04
# 1821  GHCND:USC00045721  MITCHELL CAVERNS CA US   20101228             0.04
# 1822  GHCND:USC00045721  MITCHELL CAVERNS CA US   20101229             0.04
# 1823  GHCND:USC00045721  MITCHELL CAVERNS CA US   20101230             0.04
# 1824  GHCND:USC00045721  MITCHELL CAVERNS CA US   20101231             0.04
#
# ...

# %% [markdown]
# Upon inspection, this looks like a left join. However, columns that are common to both are not discarded, and we have appended them with suffixes to provide a distinction.

# %%
climate_temp.join(precip_one_station, lsuffix='_left', rsuffix='_right')
# Out:
#              STATION_left       STATION_NAME_left ELEVATION  LATITUDE  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# ...                   ...                     ...       ...       ...
# 127015  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127016  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127017  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127018  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127019  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#          LONGITUDE  DATE_left  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# ...

# %%
inner_merged_total = pd.merge(climate_temp, climate_precip, on=['STATION', 'DATE'])
inner_merged_total.head()
# Out:
#              STATION          STATION_NAME_x ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  DLY-SNWD-PCTALL-GE001WI  \
# ...

# %%
inner_joined_total = climate_temp.join(climate_precip.set_index(['STATION', 'DATE']),
                                      lsuffix='_x', rsuffix='_y', on=['STATION', 'DATE'])
inner_joined_total.head()
# Out:
#              STATION          STATION_NAME_x ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  DLY-SNWD-PCTALL-GE001WI  \
# ...

# %%
inner_merged_total.shape
# Out:
# (123005, 48)

# %%
inner_joined_total.shape
# Out:
# (127020, 48)

# %% [markdown]
# # Concatenation
#
# Concatenating two DataFrames stitches them together along an axis.

# %%
double_precip = pd.concat([precip_one_station, precip_one_station])

# %%
double_precip.head()
# Out:
#                 STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#       DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 1460             -666            -66.6             0.16             -666
# 1461             -666            -66.6             0.16             -666
# 1462             -666            -66.6             0.16             -666
# 1463             -666            -66.6             0.16             -666
# 1464             -666            -66.6             0.17             -666
#
#       DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# ...

# %%
double_precip.shape
# Out:
# (730, 29)

# %%
reindexed = pd.concat([precip_one_station, precip_one_station], ignore_index=True)

# %%
reindexed.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6             0.16             -666
# 1             -666            -66.6             0.16             -666
# 2             -666            -66.6             0.16             -666
# 3             -666            -66.6             0.16             -666
# 4             -666            -66.6             0.17             -666
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# ...

# %%
outer_joined = pd.concat([climate_precip, climate_temp])

# %%
outer_joined.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0           -666.0            -66.6            -6.66           -666.0
# 1           -666.0            -66.6            -6.66           -666.0
# 2           -666.0            -66.6            -6.66           -666.0
# 3          -9999.0          -9999.0            -6.66          -9999.0
# 4          -9999.0          -9999.0            -6.66          -9999.0
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...

# %% [markdown]
# The ```NaN``` values appear because we care concatenating along axis 0, but the column indices do not match. This is an outer join. To drop the columns that do not have matching indices, we need an inner join.

# %%
inner_joined = pd.concat([climate_precip, climate_temp], join='inner')

# %%
inner_joined.head()
# Out:
#              STATION            STATION_NAME      DATE
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105

# %%
inner_joined_cols = pd.concat([climate_precip, climate_temp], axis=1, join='inner')

# %%
inner_joined_cols.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# ...
